# %%
data = []
hpr = 6
for dst_tor in range(0, 108, 6):
    src_tor = 516
    if src_tor == dst_tor:
        continue
    for host_idx in range(6):
        src = src_tor*hpr + host_idx
        dst = dst_tor*hpr + host_idx
        data.append((src,dst))

# %%
data = []
hpr = 6
for dst_tor in range(0, 108, 6):
    src_tor = 516
    if src_tor == dst_tor:
        continue
    data.append((src,dst))

# %%
file_name = 'test1.htsim'
with open(file_name, 'w') as file:
    # Step 3: Write each tuple in data to the file
    for srcdst in data:
        line = f"{srcdst[0]} {srcdst[1]} {10000} {100000}\n"
        file.write(line)
